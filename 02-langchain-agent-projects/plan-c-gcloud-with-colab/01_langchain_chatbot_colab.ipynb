# %%
https://colab.research.google.com/drive/1rNPYhb15eubO-x6CgD8NaoCi0PYLMh1M#scrollTo=fjSApnsyB8zw

# %%
# !pip install langchain-google-genai

# %%
from google.colab import userdata
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# LangChain (Chain-based)
# Google Gemini/Gemma integration
# Ensure GOOGLE_API_KEY environment variable is set
llm = ChatGoogleGenerativeAI(model="gemma-3-27b-it", google_api_key=userdata.get("GOOGLE_API_KEY"))
prompt = ChatPromptTemplate.from_template("{user_input}")
chain = prompt | llm

print("LangChain Chatbot (Type 'exit' to quit)")
while True:
    user_input = input("You: ")
    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Goodbye!")
        break

    response = chain.invoke({"user_input": user_input})
    print(f"AI: {response.content}")
